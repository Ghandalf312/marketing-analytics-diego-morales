# %% [markdown]
# <a href="https://colab.research.google.com/github/Ghandalf312/marketing-analytics-diego-morales/blob/main/Semana_1/Laboratorio.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# 1. Trae tu repositorio a Colab
# !git clone https://github.com/Ghandalf312/marketing-analytics-diego-morales.git
# 2. Entra a la carpeta de esta semana
# %cd marketing-analytics-diego-morales/Semana_1
# 3. Instala las dependencias
# !pip install -r requirements.txt
# Out:
# Cloning into 'marketing-analytics-diego-morales'...
# remote: Enumerating objects: 25, done.
# remote: Counting objects: 100% (25/25), done.
# remote: Compressing objects: 100% (13/13), done.
# remote: Total 25 (delta 10), reused 18 (delta 8), pack-reused 0 (from 0)
# Receiving objects: 100% (25/25), done.
# Resolving deltas: 100% (10/10), done.
# /content/marketing-analytics-diego-morales/Semana_1/marketing-analytics-diego-morales/Semana_1/marketing-analytics-diego-morales/Semana_1
# ...

# %%
from sklearn.linear_model import LinearRegression
import numpy as np

variable_x = np.array([[10], [20], [30], [40],[50]])
variable_y = np.array([15,25,35,45,55])

modelo_lr = LinearRegression()
modelo_lr.fit(variable_x,variable_y)
gasto = 100
resultado = modelo_lr.predict([[gasto]])
print(f"Las ventas proyectadas para una inversión de ${gasto} son: ${resultado[0]}")
# Out:
# Las ventas proyectadas para una inversión de $100 son: $105.0
